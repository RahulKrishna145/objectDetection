# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# #### Basic EDA

# %%
df = pd.read_csv("data\df.csv")
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.strip().str.replace(' ', '_')

# %%
df.head()
# Out:
#                             Filename  x0_(Nose)  y0_(Nose)  c0_(Nose)  \
# 0  sit_00001_sit_0000002_k_.json.png   0.579435   0.187516   0.899335
# 1  sit_00002_sit_0000003_k_.json.png   0.508805   0.134552   0.862384
# 2  sit_00003_sit_0000004_k_.json.png   0.495507   0.290921   0.867608
# 3  sit_00004_sit_0000005_k_.json.png   0.563006   0.153366   0.844512
# 4  sit_00005_sit_0000006_k_.json.png   0.525019   0.385794   0.882047
#
#    x1_(Neck)  y1_(Neck)  c1_(Neck)  x2_(RShoulder)  y2_(RShoulder)  \
# 0   0.625638   0.271302   0.781322        0.516398        0.237908
# 1   0.508796   0.257455   0.850200        0.410526        0.254695
# 2   0.566815   0.382998   0.794958        0.424235        0.369058
# 3   0.650173   0.284560   0.855136        0.523494        0.281783
# 4   0.558588   0.461226   0.886944        0.457734        0.469694
#
#    c2_(RShoulder)  ...  y15_(LEye)  c15_(LEye)  x16_(REar)  y16_(REar)  \
# ...

# %%
df.columns
# Out:
# Index(['Filename', 'x0_(Nose)', 'y0_(Nose)', 'c0_(Nose)', 'x1_(Neck)',
#        'y1_(Neck)', 'c1_(Neck)', 'x2_(RShoulder)', 'y2_(RShoulder)',
#        'c2_(RShoulder)', 'x3_(RElbow)', 'y3_(RElbow)', 'c3_(RElbow)',
#        'x4_(RWrist)', 'y4_(RWrist)', 'c4_(RWrist)', 'x5_(LShoulder)',
#        'y5_(LShoulder)', 'c5_(LShoulder)', 'x6_(LElbow)', 'y6_(LElbow)',
#        'c6_(LElbow)', 'x7_(LWrist)', 'y7_(LWrist)', 'c7_(LWrist)', 'x8_(RHip)',
#        'y8_(RHip)', 'c8_(RHip)', 'x9_(RKnee)', 'y9_(RKnee)', 'c9_(RKnee)',
#        'x10_(RFoot)', 'y10_(RFoot)', 'c10_(RFoot)', 'x11_(LHip)', 'y11_(LHip)',
#        'c11_(LHip)', 'x12_(LKnee)', 'y12_(LKnee)', 'c12_(LKnee)',
#        'x13_(LFoot)', 'y13_(LFoot)', 'c13_(LFoot)', 'x14_(REye)', 'y14_(REye)',
#        'c14_(REye)', 'x15_(LEye)', 'y15_(LEye)', 'c15_(LEye)', 'x16_(REar)',
#        'y16_(REar)', 'c16_(REar)', 'x17_(LEar)', 'y17_(LEar)', 'c17_(LEar)',
#        'class_(number)', 'class_(text)'],
#       dtype='object')

# %% [markdown]
# #### Preprocessing

# %%
df.drop(['c0_(Nose)','x1_(Neck)','y1_(Neck)','c1_(Neck)','c2_(RShoulder)','c3_(RElbow)','c4_(RWrist)','c5_(LShoulder)','c6_(LElbow)','c7_(LWrist)','c8_(RHip)','c9_(RKnee)','c10_(RFoot)','c11_(LHip)','c12_(LKnee)','c13_(LFoot)','c14_(REye)','c15_(LEye)','c16_(REar)','c17_(LEar)','class_(number)'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                             Filename  x0_(Nose)  y0_(Nose)  x2_(RShoulder)  \
# 0  sit_00001_sit_0000002_k_.json.png   0.579435   0.187516        0.516398
# 1  sit_00002_sit_0000003_k_.json.png   0.508805   0.134552        0.410526
# 2  sit_00003_sit_0000004_k_.json.png   0.495507   0.290921        0.424235
# 3  sit_00004_sit_0000005_k_.json.png   0.563006   0.153366        0.523494
# 4  sit_00005_sit_0000006_k_.json.png   0.525019   0.385794        0.457734
#
#    y2_(RShoulder)  x3_(RElbow)  y3_(RElbow)  x4_(RWrist)  y4_(RWrist)  \
# 0        0.237908     0.323704     0.324388     0.285691     0.458531
# 1        0.254695     0.383281     0.426843     0.465142     0.508835
# 2        0.369058     0.281631     0.461347     0.382093     0.514322
# 3        0.281783     0.503651     0.453981     0.463959     0.514041
# 4        0.469694     0.445190     0.581379     0.453453     0.656829
#
#    x5_(LShoulder)  ...  y13_(LFoot)  x14_(REye)  y14_(REye)  x15_(LEye)  \
# ...

# %%
le = LabelEncoder()
df['class_(text)']=le.fit_transform(df['class_(text)'])
df.head()
# Out:
#                             Filename  x0_(Nose)  y0_(Nose)  x2_(RShoulder)  \
# 0  sit_00001_sit_0000002_k_.json.png   0.579435   0.187516        0.516398
# 1  sit_00002_sit_0000003_k_.json.png   0.508805   0.134552        0.410526
# 2  sit_00003_sit_0000004_k_.json.png   0.495507   0.290921        0.424235
# 3  sit_00004_sit_0000005_k_.json.png   0.563006   0.153366        0.523494
# 4  sit_00005_sit_0000006_k_.json.png   0.525019   0.385794        0.457734
#
#    y2_(RShoulder)  x3_(RElbow)  y3_(RElbow)  x4_(RWrist)  y4_(RWrist)  \
# 0        0.237908     0.323704     0.324388     0.285691     0.458531
# 1        0.254695     0.383281     0.426843     0.465142     0.508835
# 2        0.369058     0.281631     0.461347     0.382093     0.514322
# 3        0.281783     0.503651     0.453981     0.463959     0.514041
# 4        0.469694     0.445190     0.581379     0.453453     0.656829
#
#    x5_(LShoulder)  ...  y13_(LFoot)  x14_(REye)  y14_(REye)  x15_(LEye)  \
# ...

# %% [markdown]
# #### Creating Subsets

# %%
X = df.drop(['Filename','class_(text)'],axis=1)

# %%
X.head()
# Out:
#    x0_(Nose)  y0_(Nose)  x2_(RShoulder)  y2_(RShoulder)  x3_(RElbow)  \
# 0   0.579435   0.187516        0.516398        0.237908     0.323704
# 1   0.508805   0.134552        0.410526        0.254695     0.383281
# 2   0.495507   0.290921        0.424235        0.369058     0.281631
# 3   0.563006   0.153366        0.523494        0.281783     0.503651
# 4   0.525019   0.385794        0.457734        0.469694     0.445190
#
#    y3_(RElbow)  x4_(RWrist)  y4_(RWrist)  x5_(LShoulder)  y5_(LShoulder)  ...  \
# 0     0.324388     0.285691     0.458531        0.751495        0.299148  ...
# 1     0.426843     0.465142     0.508835        0.599088        0.262906  ...
# 2     0.461347     0.382093     0.514322        0.713765        0.391449  ...
# 3     0.453981     0.463959     0.514041        0.776805        0.287250  ...
# 4     0.581379     0.453453     0.656829        0.667620        0.455702  ...
#
#    x13_(LFoot)  y13_(LFoot)  x14_(REye)  y14_(REye)  x15_(LEye)  y15_(LEye)  \
# ...

# %%
Y=df[['class_(text)']]

# %%
Y.head()
# Out:
#    class_(text)
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size=0.3, random_state=42)

# %%
print("Input train size :",x_train.shape[0])
print("Input test size :",x_test.shape[0])
print("Output train size :",y_train.shape[0])
print("Output test size :",y_test.shape[0])
# Out:
# Input train size : 35508
# Input test size : 15219
# Output train size : 35508
# Output test size : 15219

# %% [markdown]
# #### Training classifier and evaluating results

# %%
cla = RandomForestClassifier(n_estimators=100, random_state=42)
cla.fit(x_train,y_train)
# Out:
# c:\Users\aadithya\anaconda3\envs\armada\lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(random_state=42)

# %%
y_pred = cla.predict(x_test)

# %%
score = accuracy_score(y_test, y_pred)
print("accuracy is :",score)
# Out:
# accuracy is : 0.860569025560155

# %% [markdown]
# #### Running pretrained classifier on COCO keypoints

# %%
x_test.columns
# Out:
# Index(['x0_(Nose)', 'y0_(Nose)', 'x2_(RShoulder)', 'y2_(RShoulder)',
#        'x3_(RElbow)', 'y3_(RElbow)', 'x4_(RWrist)', 'y4_(RWrist)',
#        'x5_(LShoulder)', 'y5_(LShoulder)', 'x6_(LElbow)', 'y6_(LElbow)',
#        'x7_(LWrist)', 'y7_(LWrist)', 'x8_(RHip)', 'y8_(RHip)', 'x9_(RKnee)',
#        'y9_(RKnee)', 'x10_(RFoot)', 'y10_(RFoot)', 'x11_(LHip)', 'y11_(LHip)',
#        'x12_(LKnee)', 'y12_(LKnee)', 'x13_(LFoot)', 'y13_(LFoot)',
#        'x14_(REye)', 'y14_(REye)', 'x15_(LEye)', 'y15_(LEye)', 'x16_(REar)',
#        'y16_(REar)', 'x17_(LEar)', 'y17_(LEar)'],
#       dtype='object')

# %%
column_names = ['x0_(Nose)', 'y0_(Nose)', 'x2_(RShoulder)', 'y2_(RShoulder)','x3_(RElbow)', 'y3_(RElbow)', 'x4_(RWrist)', 'y4_(RWrist)',
       'x5_(LShoulder)', 'y5_(LShoulder)', 'x6_(LElbow)', 'y6_(LElbow)',
       'x7_(LWrist)', 'y7_(LWrist)', 'x8_(RHip)', 'y8_(RHip)', 'x9_(RKnee)',
       'y9_(RKnee)', 'x10_(RFoot)', 'y10_(RFoot)', 'x11_(LHip)', 'y11_(LHip)',
       'x12_(LKnee)', 'y12_(LKnee)', 'x13_(LFoot)', 'y13_(LFoot)',
       'x14_(REye)', 'y14_(REye)', 'x15_(LEye)', 'y15_(LEye)', 'x16_(REar)',
       'y16_(REar)', 'x17_(LEar)', 'y17_(LEar)']

# %%
df = pd.read_csv("data\cocoset.csv")
df.columns = df.columns.str.lstrip()
df.columns = df.columns.str.strip().str.replace(' ', '_')

# %%
df1 = df.dropna()

# %%
col_list = ['nose', 'left_eye', 'right_eye', 'left_ear', 'right_ear','left_shoulder', 'right_shoulder', 'left_elbow', 'right_elbow','left_wrist', 'right_wrist', 'left_hip', 'right_hip', 'left_knee','right_knee', 'left_ankle', 'right_ankle']

# %%
for col in col_list:
    x = col+'x'
    y = col+'y'
    z = col+'z'
    df1[[x, y,z]] = df1[col].str.strip('()').str.split(',', expand=True)
    df1.drop([col], inplace=True, axis=1)
    df1.drop([z],inplace=True,axis=1)
# Out:
# C:\Users\aadithya\AppData\Local\Temp\ipykernel_36324\4057535044.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[[x, y,z]] = df1[col].str.strip('()').str.split(',', expand=True)
# C:\Users\aadithya\AppData\Local\Temp\ipykernel_36324\4057535044.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[[x, y,z]] = df1[col].str.strip('()').str.split(',', expand=True)
# C:\Users\aadithya\AppData\Local\Temp\ipykernel_36324\4057535044.py:5: SettingWithCopyWarning:
# ...

# %%
col_list = ['nosex', 'nosey', 'left_eyex', 'left_eyey', 'right_eyex', 'right_eyey',
       'left_earx', 'left_eary', 'right_earx', 'right_eary', 'left_shoulderx',
       'left_shouldery', 'right_shoulderx', 'right_shouldery', 'left_elbowx',
       'left_elbowy', 'right_elbowx', 'right_elbowy', 'left_wristx',
       'left_wristy', 'right_wristx', 'right_wristy', 'left_hipx', 'left_hipy',
       'right_hipx', 'right_hipy', 'left_kneex', 'left_kneey', 'right_kneex',
       'right_kneey', 'left_anklex', 'left_ankley', 'right_anklex',
       'right_ankley']

# %%
df1 = df1.apply(pd.to_numeric, errors='coerce')
df1 = df1.dropna()
df1
# Out:
#         nosex  nosey  left_eyex  left_eyey  right_eyex  right_eyey  left_earx  \
# 24        248    175        260        167         241         167        270
# 32        252    369        255        364         247         363        259
# 50        249    184        255        180         246         179        260
# 80        323     31        334         24         316          23        345
# 83        168     41        175         35         166          34        181
# ...       ...    ...        ...        ...         ...         ...        ...
# 262175    268     94        279         88         262          81        295
# 262279    525     26        527         20         520          21        531
# 262302    438     28        442         23         433          24        450
# 262317    270    154        282        145         257         142        300
# 262345    114    240        116        238         111         238        121
#
# ...

# %%
scaler = MinMaxScaler()
for col in col_list:
    df1[col] = df1[col].apply(pd.to_numeric, errors='coerce')
    df1[col] = scaler.fit_transform(df1[[col]])

# %%
df1.head()
# Out:
#        nosex     nosey  left_eyex  left_eyey  right_eyex  right_eyey  \
# 24  0.384740  0.299130   0.399676   0.289931    0.375405    0.289931
# 32  0.391234  0.636522   0.391586   0.631944    0.385113    0.630208
# 50  0.386364  0.314783   0.391586   0.312500    0.383495    0.310764
# 80  0.506494  0.048696   0.519417   0.041667    0.496764    0.039931
# 83  0.254870  0.066087   0.262136   0.060764    0.254045    0.059028
#
#     left_earx  left_eary  right_earx  right_eary  ...  right_hipx  right_hipy  \
# 24   0.409091   0.292388    0.368760    0.288696  ...    0.333333    0.501742
# 32   0.391234   0.631488    0.373591    0.638261  ...    0.367816    0.721254
# 50   0.392857   0.316609    0.384863    0.313043  ...    0.384236    0.371080
# 80   0.530844   0.055363    0.492754    0.045217  ...    0.448276    0.182927
# 83   0.264610   0.067474    0.249597    0.057391  ...    0.216749    0.120209
#
#     left_kneex  left_kneey  right_kneex  right_kneey  left_anklex  \
# ...

# %%
df1.shape
# Out:
# (8475, 34)

# %%
df1.columns = ['x0_(Nose)', 'y0_(Nose)', 'x2_(RShoulder)', 'y2_(RShoulder)',
       'x3_(RElbow)', 'y3_(RElbow)', 'x4_(RWrist)', 'y4_(RWrist)',
       'x5_(LShoulder)', 'y5_(LShoulder)', 'x6_(LElbow)', 'y6_(LElbow)',
       'x7_(LWrist)', 'y7_(LWrist)', 'x8_(RHip)', 'y8_(RHip)', 'x9_(RKnee)',
       'y9_(RKnee)', 'x10_(RFoot)', 'y10_(RFoot)', 'x11_(LHip)', 'y11_(LHip)',
       'x12_(LKnee)', 'y12_(LKnee)', 'x13_(LFoot)', 'y13_(LFoot)',
       'x14_(REye)', 'y14_(REye)', 'x15_(LEye)', 'y15_(LEye)', 'x16_(REar)',
       'y16_(REar)', 'x17_(LEar)', 'y17_(LEar)']

# %%
y_output = cla.predict(df1)

# %%
y_output = df = pd.DataFrame(y_output)

# %%
y_output.value_counts()
# Out:
# 0
# 1    8374
# 0     101
# Name: count, dtype: int64

# %%
y_poses = y_output.replace(0,'sitting')
y_poses = y_poses.replace(1,'standing')

# %%
y_poses
# Out:
#              0
# 0      sitting
# 1     standing
# 2     standing
# 3     standing
# 4     standing
# ...        ...
# 8470  standing
# 8471  standing
# 8472  standing
# 8473  standing
# 8474  standing
#
# [8475 rows x 1 columns]

# %%
y_poses.value_counts()
# Out:
# 0
# standing    8374
# sitting      101
# Name: count, dtype: int64
